# %%
import sys, os
from plot_XY_time_series import *

print(help(webmap_w_grid), "\n", "\n")
print(help(click_to_coords), "\n", "\n")
print(help(plot_raw_smoothed_TS), "\n", "\n")
# Out:
# /home/lsharwood/miniconda3/envs/.helpers38/lib/python3.8/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.11.0-CAPI-1.17.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# Help on function webmap_w_grid in module plot_XY_time_series:
#
# webmap_w_grid(project_name='PARAGUAY')
#     creates leaflet webmap with lat-lon coordinates in bottom-right corner
#     turn on grid layer to find what grid number an area is in. to add marker, toggle off grid layer
#
#     1. project_name = grids to plot. subsets LUCinLA_grid_8858.gpkg where the project_name string is in grid's CEL_proj column
#         ex) project_name="PARAGUAY" default
#         other options: "CHILE", "WSA", "BRAZIL"
#
# None
#
#
# Help on function click_to_coords in module plot_XY_time_series:
#
# click_to_coords(raw_coords, class_name)
#     reformats lat-lon coordinates by replacing : with ,
# ...

# %%
pt1=click_to_coords("-26.55087 : -54.9663", "grass")
pt2=click_to_coords("-26.55201 : -54.97725", "tree")
pt3=click_to_coords("-26.55706 : -54.96898", "crop")

#######################################################

plot_raw_smoothed_TS(web_coord_list= [ pt1 , pt2, pt3 ])
# Out:
# /home/sandbox-cel/paraguay_lc/stac/grid/grass_tree_crop_brdfZeroNA_check.txt
